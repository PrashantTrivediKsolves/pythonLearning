# %%
import pandas as pd

# %%
pd.DataFrame({'Yes': [50, 21], 'No': [131, 2]})
# Out:
#    Yes   No
# 0   50  131
# 1   21    2

# %%
pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'], 'Sue': ['Pretty good.', 'Bland.']})
# Out:
#              Bob           Sue
# 0    I liked it.  Pretty good.
# 1  It was awful.        Bland.

# %%
pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'], 
              'Sue': ['Pretty good.', 'Bland.']},
             index=['Product A', 'Product B'])
# Out:
#                      Bob           Sue
# Product A    I liked it.  Pretty good.
# Product B  It was awful.        Bland.

# %%
pd.Series([1, 2, 3, 4, 5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
reviews.set_index("title")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 reviews.set_index("title")
#
# NameError: name 'reviews' is not defined

# %%
reviews.loc["Nicosia 2013 Vulkà Bianco (Etna)": "Quinta dos Avidagos 2011 Avidagos Red (Douro)"]
# Out:
# Empty DataFrame
# Columns: [country, description, designation, points, price, province, region_1, region_2, taster_name, taster_twitter_handle, title, variety, winery]
# Index: []

# %%
pd.Series([30, 35, 40], index=['2015 Sales', '2016 Sales', '2017 Sales'], name='Product A')
# Out:
# 2015 Sales    30
# 2016 Sales    35
# 2017 Sales    40
# Name: Product A, dtype: int64

# %%
wine_reviews = pd.read_csv("/home/prashantksi200/Desktop/pythonLearning/winemag-data-130k-v2.csv")

wine_reviews.shape
# Out:
# (129971, 14)

# %%
wine_reviews.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
wine_reviews = pd.read_csv("/home/prashantksi200/Desktop/pythonLearning/winemag-data-130k-v2.csv", index_col=0)
wine_reviews.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
reviews = pd.read_csv("/home/prashantksi200/Desktop/pythonLearning/winemag-data-130k-v2.csv", index_col=0)
pd.set_option('display.max_rows', 5)

# %%
reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %%
reviews.country
# Out:
# 0            Italy
# 1         Portugal
#             ...
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
pd.set_option('display.max_rows', 5)

df = pd.DataFrame({'num': range(100)})
print(df)
# Out:
#     num
# 0     0
# 1     1
# ..  ...
# 98   98
# 99   99
#
# [100 rows x 1 columns]

# %%
reviews.country
# Out:
# 0            Italy
# 1         Portugal
#             ...
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
reviews['country'][0]
# Out:
# 'Italy'

# %%
reviews.iloc[0]
# Out:
# country                                                    Italy
# description    Aromas include tropical fruit, broom, brimston...
#                                      ...
# variety                                              White Blend
# winery                                                   Nicosia
# Name: 0, Length: 13, dtype: object

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Score': [85, 90, 95]
}

df = pd.DataFrame(data, index=['a', 'b', 'c'])

print(df)
# Out:
#       Name  Score
# a    Alice     85
# b      Bob     90
# c  Charlie     95

# %%
# Access row with label 'b'
print(df.loc['b'])
# Out:
# Name     Bob
# Score     90
# Name: b, dtype: object

# %%
# Access 'Score' of row 'c'
print(df.loc['c', 'Score'])  # 95
# Out:
# 95

# %%
#  Summary Table
# Feature	loc[]	iloc[]
# Index type	Label-based	Integer position-based
# Row Example	df.loc['a']	df.iloc[0]
# Cell Example	df.loc['a', 'Score']	df.iloc[0, 1]
# Can slice?	✅ Yes	✅ Yes

# %%
# loc slicing (inclusive of last)
df.loc['a':'b']  # includes both 'a' and 'b'
# Out:
#     Name  Score
# a  Alice     85
# b    Bob     90

# %%
# iloc slicing (exclusive of last)
df.iloc[0:2]  # includes row 0 and 1, not 2
# Out:
#     Name  Score
# a  Alice     85
# b    Bob     90

# %%
reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %%
reviews.iloc[:,0]
# Out:
# 0            Italy
# 1         Portugal
#             ...
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
reviews.iloc[-5:]
# Out:
#         country                                        description  \
# 129966  Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967       US  Citation is given as much as a decade of bottl...
# 129968   France  Well-drained gravel soil gives this wine its c...
# 129969   France  A dry style of Pinot Gris, this is crisp with ...
# 129970   France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price province  \
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0    Mosel
# 129967                                     NaN      90   75.0   Oregon
# 129968                                   Kritt      90   30.0   Alsace
# 129969                                     NaN      90   32.0   Alsace
# 129970           Lieu-dit Harth Cuvée Caroline      90   21.0   Alsace
#
#        region_1      region_2         taster_name taster_twitter_handle  \
# ...

# %%
reviews.loc[0, 'country']
# Out:
# 'Italy'

# %%
reviews.loc[:, ['taster_name', 'taster_twitter_handle', 'points']]
# Out:
#           taster_name taster_twitter_handle  points
# 0       Kerin O’Keefe          @kerinokeefe      87
# 1          Roger Voss            @vossroger      87
# ...               ...                   ...     ...
# 129969     Roger Voss            @vossroger      90
# 129970     Roger Voss            @vossroger      90
#
# [129971 rows x 3 columns]

# %%
reviews.loc["Nicosia 2013 Vulkà Bianco (Etna)": "Quinta dos Avidagos 2011 Avidagos Red (Douro)"]
# Out:
# Empty DataFrame
# Columns: [country, description, designation, points, price, province, region_1, region_2, taster_name, taster_twitter_handle, title, variety, winery]
# Index: []

# %%
reviews.set_index("title")
# Out:
#                                                      country  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                      Italy
# Quinta dos Avidagos 2011 Avidagos Red (Douro)       Portugal
# ...                                                      ...
# Domaine Marcel Deiss 2012 Pinot Gris (Alsace)         France
# Domaine Schoffit 2012 Lieu-dit Harth Cuvée Caro...    France
#
#                                                                                           description  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                   Aromas include tropical fruit, broom, brimston...
# Quinta dos Avidagos 2011 Avidagos Red (Douro)       This is ripe and fruity, a wine that is smooth...
# ...                                                                                               ...
# Domaine Marcel Deiss 2012 Pinot Gris (Alsace)       A dry style of Pinot Gris, this is crisp with ...
# ...

# %%
reviews.loc["Nicosia 2013 Vulkà Bianco (Etna)": "Quinta dos Avidagos 2011 Avidagos Red (Douro" , ["country", "description"]]
# Out:
# Empty DataFrame
# Columns: [country, description]
# Index: []

# %%
reviews = reviews.sort_index()

# %%
reviews.loc[
    "Nicosia 2013 Vulkà Bianco (Etna)" : "Quinta dos Avidagos 2011 Avidagos Red (Douro)",
    ["country", "description"]
]
# Out:
# Empty DataFrame
# Columns: [country, description]
# Index: []

# %%
reviews.country == 'Italy'
# Out:
# 0          True
# 1         False
#           ...
# 129969    False
# 129970    False
# Name: country, Length: 129971, dtype: bool

# %%
reviews.loc[reviews.country == 'Italy']
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# ...        ...                                                ...
# 129961   Italy  Intense aromas of wild cherry, baking spice, t...
# 129962   Italy  Blackberry, cassis, grilled herb and toasted a...
#
#                       designation  points  price           province  region_1  \
# 0                    Vulkà Bianco      87    NaN  Sicily & Sardinia      Etna
# 6                         Belsito      87   16.0  Sicily & Sardinia  Vittoria
# ...                           ...     ...    ...                ...       ...
# 129961                        NaN      90   30.0  Sicily & Sardinia   Sicilia
# 129962  Sàgana Tenuta San Giacomo      90   40.0  Sicily & Sardinia   Sicilia
#
#        region_2    taster_name taster_twitter_handle  \
# ...

# %%
reviews.loc[(reviews.country == 'Italy') & (reviews.points >= 90)]
# Out:
#        country                                        description  \
# 120      Italy  Slightly backward, particularly given the vint...
# 130      Italy  At the first it was quite muted and subdued, b...
# ...        ...                                                ...
# 129961   Italy  Intense aromas of wild cherry, baking spice, t...
# 129962   Italy  Blackberry, cassis, grilled herb and toasted a...
#
#                       designation  points  price           province region_1  \
# 120           Bricco Rocche Prapó      92   70.0           Piedmont   Barolo
# 130         Bricco Rocche Brunate      91   70.0           Piedmont   Barolo
# ...                           ...     ...    ...                ...      ...
# 129961                        NaN      90   30.0  Sicily & Sardinia  Sicilia
# 129962  Sàgana Tenuta San Giacomo      90   40.0  Sicily & Sardinia  Sicilia
#
#        region_2    taster_name taster_twitter_handle  \
# ...

# %%
reviews.loc[(reviews.country == 'Italy') | (reviews.points >= 90)]
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# ...        ...                                                ...
# 129969  France  A dry style of Pinot Gris, this is crisp with ...
# 129970  France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 6                             Belsito      87   16.0  Sicily & Sardinia
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#         region_1 region_2    taster_name taster_twitter_handle  \
# 0           Etna      NaN  Kerin O’Keefe          @kerinokeefe
# ...

# %%
reviews.loc[reviews.country.isin(['Italy', 'France'])]
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# ...        ...                                                ...
# 129969  France  A dry style of Pinot Gris, this is crisp with ...
# 129970  France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 6                             Belsito      87   16.0  Sicily & Sardinia
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#         region_1 region_2    taster_name taster_twitter_handle  \
# 0           Etna      NaN  Kerin O’Keefe          @kerinokeefe
# ...

# %%
reviews.loc[reviews.price.notnull()]
# Out:
#          country                                        description  \
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price province  \
# 1                            Avidagos      87   15.0    Douro
# 2                                 NaN      87   14.0   Oregon
# ...                               ...     ...    ...      ...
# 129969                            NaN      90   32.0   Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0   Alsace
#
#                  region_1           region_2   taster_name  \
# 1                     NaN                NaN    Roger Voss
# 2       Willamette Valley  Willamette Valley  Paul Gregutt
# ...

# %%
reviews.loc[reviews.price.isnull()]
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 13       Italy  This is dominated by oak and oak-driven aromas...
# ...        ...                                                ...
# 129893   Italy  Aromas of passion fruit, hay and a vegetal not...
# 129964  France  Initially quite muted, this wine slowly develo...
#
#                          designation  points  price           province  \
# 0                       Vulkà Bianco      87    NaN  Sicily & Sardinia
# 13                             Rosso      87    NaN  Sicily & Sardinia
# ...                              ...     ...    ...                ...
# 129893                  Corte Menini      91    NaN             Veneto
# 129964  Domaine Saint-Rémy Herrenweg      90    NaN             Alsace
#
#               region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %%
reviews['critic'] = 'everyone'
reviews['critic']
# Out:
# 0         everyone
# 1         everyone
#             ...
# 129969    everyone
# 129970    everyone
# Name: critic, Length: 129971, dtype: object

# %%
reviews['index_backwards'] = range(len(reviews), 0, -1)
reviews['index_backwards']
# Out:
# 0         129971
# 1         129970
#            ...
# 129969         2
# 129970         1
# Name: index_backwards, Length: 129971, dtype: int64

# %%
reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %%
reviews.isna().sum().head()
# Out:
# country           63
# description        0
# designation    37465
# points             0
# price           8996
# dtype: int64

# %%
#  Drop or Fill Missing Values
# 🧹 Drop rows with any NaN:

df.dropna()
# Out:
#       Name  Score
# a    Alice     85
# b      Bob     90
# c  Charlie     95

# %%
reviews.fillna("Unknown")
reviews['price'].fillna(reviews['price'].mean())  # Fill with average
# Out:
# 0         35.363389
# 1         15.000000
#             ...
# 129969    32.000000
# 129970    21.000000
# Name: price, Length: 129971, dtype: float64

# %%
reviews.isna().sum().head()
# Out:
# country           63
# description        0
# designation    37465
# points             0
# price           8996
# dtype: int64

# %%
# when you use methods like .isnull(), .fillna(), .dropna(), or even .set_index(), the changes do not automatically modify the original DataFrame unless you:



df = pd.DataFrame({
    'name': ['Alice', 'Bob', 'Charlie'],
    'score': [80, 90, 70]
})

# Add 10 bonus points to each score
df['score'] = df['score'].apply(lambda x: x + 10)
df
# Out:
#       name  score
# 0    Alice     90
# 1      Bob    100
# 2  Charlie     80

# %%
# When used on a DataFrame
# You can apply a function row-wise or column-wise by using the axis argument:

# axis=0: Apply to each column

# axis=1: Apply to each row

# Combine 'name' and 'score' into a single string per row
df.apply(lambda row: f"{row['name']} scored {row['score']}", axis=1)
# Out:
# 0      Alice scored 90
# 1       Bob scored 100
# 2    Charlie scored 80
# dtype: object

# %%
df
# Out:
#       name  score
# 0    Alice     90
# 1      Bob    100
# 2  Charlie     80

# %%
df['summary'] = df.apply(lambda row: f"{row['name']} scored {row['score']}", axis=1)
df
# Out:
#       name  score            summary
# 0    Alice     90    Alice scored 90
# 1      Bob    100     Bob scored 100
# 2  Charlie     80  Charlie scored 80

# %%
# Convert scores to grade letters
def grade(x):
    if x >= 90:
        return 'A'
    elif x >= 80:
        return 'B'
    elif x >= 70:
        return 'C'
    else:
        return 'D'

df['grade'] = df['score'].apply(grade)
df
# Out:
#       name  score            summary grade
# 0    Alice     90    Alice scored 90     A
# 1      Bob    100     Bob scored 100     A
# 2  Charlie     80  Charlie scored 80     B

# %%
# Summary functions 

reviews.points.describe().head()
# Out:
# count    129971.000000
# mean         88.447138
# std           3.039730
# min          80.000000
# 25%          86.000000
# Name: points, dtype: float64

# %%
df.describe()
# Out:
#        score
# count    3.0
# mean    90.0
# ...      ...
# 75%     95.0
# max    100.0
#
# [8 rows x 1 columns]

# %%
#  Want to See This for All Columns?

df.describe(include='all').head()  # Includes text, dates, etc.
# Out:
#          name  score          summary grade
# count       3    3.0                3     3
# unique      3    NaN                3     2
# top     Alice    NaN  Alice scored 90     A
# freq        1    NaN                1     2
# mean      NaN   90.0              NaN   NaN

# %%
reviews.taster_name.unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 reviews.taster_name.unique()
#
# NameError: name 'reviews' is not defined

# %%
reviews.taster_name.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_37615/2543398593.py in ?()
# ----> 1 reviews.taster_name.value_counts()
#
# ~/.local/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'taster_name'

# %%
# Key Points:
# It's often used for frequency analysis of categorical (text) data.

# It automatically sorts results in descending order.

# If you want to include missing values (NaN), you can pass dropna=False:

reviews.taster_name.value_counts(dropna=False)
# Out:
# taster_name
# NaN                  26244
# Roger Voss           25514
#                      ...
# Fiona Adams             27
# Christina Pickard        6
# Name: count, Length: 20, dtype: int64

# %%
review_points_mean = reviews.points.mean()
reviews.points.map(lambda p: p - review_points_mean)
# Out:
# 0        -1.447138
# 1        -1.447138
#             ...
# 129969    1.552862
# 129970    1.552862
# Name: points, Length: 129971, dtype: float64

# %%
def remean_points(row):
    row.points = row.points - review_points_mean
    return row

reviews.apply(remean_points, axis='columns')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 5
#       2     row.points = row.points - review_points_mean
#       3     return row
# ----> 5 reviews.apply(remean_points, axis='columns')
#
# NameError: name 'reviews' is not defined

# %%
# Note that map() and apply() return new, transformed Series and DataFrames, respectively. They don't modify the original data they're called on. If we look at the first row of reviews, we can see that it still has its original points value.

# %%
reviews.price.dtype
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_37615/4219869730.py in ?()
# ----> 1 reviews.price.dtype
#
# ~/.local/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'price'

# %%
reviews.dtypes
# Out:
# country            object
# description        object
#                     ...
# critic             object
# index_backwards     int64
# Length: 15, dtype: object

# %%
reviews[pd.isnull(reviews.country)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_37615/1811691501.py in ?()
# ----> 1 reviews[pd.isnull(reviews.country)]
#
# ~/.local/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'country'

# %%
reviews = reviews.region_2.fillna("Unknown")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_37615/3702196673.py in ?()
# ----> 1 reviews = reviews.region_2.fillna("Unknown")
#
# ~/.local/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'region_2'

# %%
# Out:
# 0         Unknown
# 1         Unknown
#            ...
# 129969    Unknown
# 129970    Unknown
# Name: region_2, Length: 129971, dtype: object

# %%
import pandas as pd

data = {
    'Department': ['HR', 'IT', 'HR', 'Finance', 'IT', 'Finance', 'HR'],
    'Employee': ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank', 'Grace'],
    'Salary': [50000, 60000, 55000, 70000, 65000, 72000, 52000]
}

df = pd.DataFrame(data)
print(df)
# Out:
#   Department Employee  Salary
# 0         HR    Alice   50000
# 1         IT      Bob   60000
# 2         HR  Charlie   55000
# 3    Finance    David   70000
# 4         IT      Eve   65000
# 5    Finance    Frank   72000
# 6         HR    Grace   52000

# %%
df.groupby('Department')['Salary'].sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 df.groupby('Department')['Salary'].sum()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1363, in GroupBy.__getattr__(self, attr)
#    1360 if attr in self.obj:
#    1361     return self[attr]
# -> 1363 raise AttributeError(
#    1364     f"'{type(self).__name__}' object has no attribute '{attr}'"
#    1365 )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'groupby'
